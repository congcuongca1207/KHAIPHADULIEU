# %% [markdown]
# # Dữ liệu bán hàng của một cửa hàng xe đạp
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>

# %%
#@title Nhập thư viện và dữ liệu

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

df = pd.read_csv('sales_data.csv')
df.head()
# Out:
# <ipython-input-12-a09e50f0b74a>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7643 entries, 0 to 7642
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7643 non-null   object
#  1   Day               7643 non-null   int64
#  2   Month             7643 non-null   object
#  3   Year              7643 non-null   int64
#  4   Customer_Age      7643 non-null   int64
#  5   Age_Group         7643 non-null   object
#  6   Customer_Gender   7643 non-null   object
#  7   Country           7643 non-null   object
#  8   State             7643 non-null   object
#  9   Product_Category  7643 non-null   object
#  10  Sub_Category      7643 non-null   object
#  11  Product           7643 non-null   object
#  12  Order_Quantity    7642 non-null   float64
#  13  Unit_Cost         7642 non-null   float64
#  14  Unit_Price        7642 non-null   float64
#  15  Profit            7642 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Day         Year  Customer_Age  Order_Quantity    Unit_Cost  \
# count  7643.000000  7643.000000   7643.000000     7642.000000  7642.000000
# mean     15.403768  2014.588774     36.141437       14.035593     9.193405
# std       8.880167     1.114518     11.007290        8.832830    16.896570
# min       1.000000  2013.000000     17.000000        1.000000     2.000000
# 25%       8.000000  2014.000000     28.000000        6.000000     2.000000
# 50%      15.000000  2014.000000     35.000000       13.000000     2.000000
# 75%      23.000000  2016.000000     43.000000       22.000000     4.000000
# max      31.000000  2016.000000     87.000000       32.000000    59.000000
#
#         Unit_Price       Profit         Cost      Revenue
# count  7642.000000  7642.000000  7642.000000  7642.000000
# mean     24.408794   111.172075    79.916252   191.088328
# std      45.430637   207.095020   141.869081   347.815830
# min       5.000000     2.000000     2.000000     4.000000
# ...

# %% [markdown]
# ### Câu 1. Tóm tắt thống kê mô tả của dữ liệu và giải thích

# %% [markdown]
# ## 1. Tổng quát về lợi nhuận (Profit), doanh thu (Revenue), và chi phí (Cost)

# %% [markdown]
# ### Câu 2. Vẽ biểu đồ histogram trên cột lợi nhuận (Profit)

# %%
# YOUR CODE HERE

# %% [markdown]
# Dựa trên biểu đồ histogram, mô tả mối quan hệ giữa giá trị trung bình (mean), trung vị (median), và mode của lợi nhuận (profit).
#
# <ol type='A'>
#     <li>mode < mean < median</li>
#     <li>median < mean < mode</li>
#     <li>mean < mode < median</li>
#     <li>mode < median < mean</li>
# </ol>

# %% [markdown]
# ### Câu 3. Vẽ biểu đồ hộp (boxplot) trên cột lợi nhuận (Profit)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Câu 4. Dùng bar chart (biểu đồ cột) để trực quan hoá tổng lợi nhuận (Profit) theo năm (Year)

# %%
# YOUR CODE HERE

# %% [markdown]
# Loại biểu đồ nào dưới đây có thể thay bar chart (biểu đồ cột) để mô tả hiệu quả lợi nhuận theo từng năm
#
# <ol type='A'>
#     <li>Biểu đồ đường (line chart)</li>
#     <li>Biểu đồ phân phối (histogram)</li>
#     <li>Biểu đồ tròn (pie chart)</li>
#     <li>Biểu đồ cột chồng (stacked bar chart)</li>
# </ol>

# %% [markdown]
# ### Câu 5. Dùng bar chart (biểu đồ cột) để trực quan hoá tổng lợi nhuận (Profit) theo tháng (Month)

# %%
# YOUR CODE HERE

# %% [markdown]
# Dữ liệu này đã được thu thập từ ngày 01-01-2011 đến ngày 31-07-2016. Điều này có nghĩa là biểu đồ trước đó có xu hướng lệch về các tháng từ tháng 1 đến tháng 7. Do đó, khi đi làm, có thể cấp trên sẽ muốn bạn vẽ lại biểu đồ chỉ sử dụng dữ liệu từ năm 2011 đến 2015.
#
# Biểu đồ mới sẽ khác biểu đồ cũ như thế nào?
#
# <ol type='A'>
#     <li>Biểu đồ mới sẽ cho thấy lợi nhuận có xu hướng tăng khi đến cuối năm.</li>
#     <li>Biểu đồ mới sẽ không còn thấy đỉnh lợi nhuận tăng đột ngột vào tháng 11 và tháng 12.</li>
#     <li>Tháng có lợi nhuận thấp nhất sẽ giống nhau trên cả hai biểu đồ.</li>
#     <li>Không có sự khác biệt lớn giữa hai biểu đồ.</li>
# </ol>

# %% [markdown]
# ### Câu 6. Trực quan hoá tỉ lệ lợi nhận/chi phí (ratio of profit/cost) theo năm (Year)

# %%
# YOUR CODE HERE

# %% [markdown]
# Tại sao tỷ lệ lợi nhuận so với chi phí giảm từ năm 2014 đến 2015?
#
# <ol type='A'>
#     <li><code>Lợi nhuận</code> tăng trong khi <code>Chi phí</code> giảm</li>
#     <li><code>Lợi nhuận</code> giảm trong khi <code>Chi phí</code> tăng</li>
#     <li>Cả <code>Lợi nhuận</code> và <code>Chi phí</code> đều tăng, nhưng <code>Chi phí</code> tăng theo tỷ lệ lớn hơn.</li>
#     <li>Cả <code>Lợi nhuận</code> và <code>Chi phí</code> đều giảm, nhưng <code>Lợi nhuận</code> giảm theo tỷ lệ lớn hơn.</li>
# </ol>

# %% [markdown]
# ## 2. Phân tích theo nhóm (Category)

# %% [markdown]
# ### Câu 7. Vẽ biểu đồ thể hiện số lượng sản phẩm đã bán trong từng danh mục (Category). Mỗi sản phẩm bán tương ứng với một dòng trong dữ liệu.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Câu 8. Trong danh mục Phụ kiện (Accessories), các danh mục con (sub category) nào có số lượng sản phẩm bán ra nhiều hơn? Vẽ biểu đồ thể hiện điều đó.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Câu 9. Trong các danh mục con (sub category) thuộc Phụ kiện (Accessories), danh mục nào mang lại tổng lợi nhuận lớn nhất cho cửa hàng? Vẽ biểu đồ thể hiện điều đó.

# %%
# YOUR CODE HERE
